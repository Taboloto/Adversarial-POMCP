# %% [markdown]
# # Inizializzazione

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd ../content/drive/MyDrive/AI/NEW/PROGRAMMA/pomcp-blackbox/build
# Out:
# [Errno 2] No such file or directory: '../content/drive/MyDrive/AI/NEW/PROGRAMMA/pomcp-blackbox/build'
# /content/drive/MyDrive/AI/NEW/PROGRAMMA/src

# %%
# !chmod 775 'twoacts'
# Out:
# chmod: cannot access 'twoacts': No such file or directory

# %%
ls -l
# Out:
# total 69
# -rw-------  1 root root  1169 Apr 19 12:58  belief_dataset_generation.py
# -rw-------  1 root root  5571 May 14 13:35  constrained_random_jacobian_pomcp_bash_print_custom.py
# drwx------ 13 root root  4096 May 16 10:26  DNN_MODELS/
# -rw-------  1 root root     0 Apr 19 12:58  __init__.py
# -rw-------  1 root root  7627 May 16 11:44  jacobian_pomcp_bash_print_custom.py
# drwx------  2 root root  4096 May 14 13:35  MISC/
# drwx------  2 root root  4096 Apr 28 16:00  PLOTS/
# drwx------  2 root root  4096 Apr 19 13:07  __pycache__/
# -rw-------  1 root root  5586 May 14 15:30  random_jacobian_pomcp_bash_print_custom.py
# -rw-------  1 root root  1771 Apr 19 12:58  simplex_displacement.py
# drwx------  2 root root  4096 Apr 28 15:59  TESTS/
# drwx------  2 root root  4096 Apr 28 16:00 'TESTS CUSTOM'/
# -rw-------  1 root root  2357 May 14 19:30  utils_custom.py
# -rw-------  1 root root 10146 May 14 17:16  utils_ORIGINALE.py
# -rw-------  1 root root 10146 May 14 13:46  utils.py

# %% [markdown]
# # Run

# %%
cd ../../src
# Out:
# [Errno 2] No such file or directory: '../../src'
# /content/drive/MyDrive/AI/NEW/PROGRAMMA/src

# %%
# !python3 jacobian_pomcp_custom.py 190 64_32_32_32 0.2 800 0.5 20 40 0.3 1
# Out:
# ['jacobian_pomcp_bash_print_custom.py', '190', '64_32_32_32', '0.2', '800', '0.5', '20', '40', '0.3', '1']
# conf: 190 ['64', '32', '32', '32'] 0.2 800 0.5 20 40
#
# 2022-05-16 14:02:05.460920: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 81)                6642
#
#  dense_1 (Dense)             (None, 64)                5248
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 16,148
# Trainable params: 16,148
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# Substitute training epoch: 0	len_df: 190
# RANDOMMMMMMM
# Dnn Accuracy: 88.33
# accs: [88.33]
#
# Substitute training epoch: 1	len_df: 230
# RANDOMMMMMMM
# Dnn Accuracy: 93.0
# accs: [88.33, 93.0]
#
# Substitute training epoch: 2	len_df: 270
# RANDOMMMMMMM
# Dnn Accuracy: 92.0
# accs: [88.33, 93.0, 92.0]
#
# Substitute training epoch: 3	len_df: 310
# RANDOMMMMMMM
# Dnn Accuracy: 94.67
# accs: [88.33, 93.0, 92.0, 94.67]
#
# Substitute training epoch: 4	len_df: 350
# RANDOMMMMMMM
# Dnn Accuracy: 96.33
# accs: [88.33, 93.0, 92.0, 94.67, 96.33]
#
# Substitute training epoch: 5	len_df: 390
# RANDOMMMMMMM
# Dnn Accuracy: 96.67
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67]
#
# Substitute training epoch: 6	len_df: 430
# RANDOMMMMMMM
# Dnn Accuracy: 97.67
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67]
#
# Substitute training epoch: 7	len_df: 470
# RANDOMMMMMMM
# Dnn Accuracy: 96.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0]
#
# Substitute training epoch: 8	len_df: 510
# RANDOMMMMMMM
# Dnn Accuracy: 93.67
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67]
#
# Substitute training epoch: 9	len_df: 550
# RANDOMMMMMMM
# Dnn Accuracy: 94.67
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67]
#
# Substitute training epoch: 10	len_df: 590
# RANDOMMMMMMM
# Dnn Accuracy: 93.67
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67]
#
# Substitute training epoch: 11	len_df: 630
# RANDOMMMMMMM
# Dnn Accuracy: 92.33
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33]
#
# Substitute training epoch: 12	len_df: 670
# RANDOMMMMMMM
# Dnn Accuracy: 94.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0]
#
# Substitute training epoch: 13	len_df: 710
# RANDOMMMMMMM
# Dnn Accuracy: 94.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0]
#
# Substitute training epoch: 14	len_df: 750
# RANDOMMMMMMM
# Dnn Accuracy: 93.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0]
#
# Substitute training epoch: 15	len_df: 790
# RANDOMMMMMMM
# Dnn Accuracy: 93.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0, 93.0]
#
# Substitute training epoch: 16	len_df: 830
# RANDOMMMMMMM
# Dnn Accuracy: 93.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0, 93.0, 93.0]
#
# Substitute training epoch: 17	len_df: 870
# RANDOMMMMMMM
# Dnn Accuracy: 91.33
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0, 93.0, 93.0, 91.33]
#
# Substitute training epoch: 18	len_df: 910
# RANDOMMMMMMM
# Dnn Accuracy: 92.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0, 93.0, 93.0, 91.33, 92.0]
#
# Substitute training epoch: 19	len_df: 950
# RANDOMMMMMMM
# Dnn Accuracy: 92.0
# accs: [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0, 93.0, 93.0, 91.33, 92.0, 92.0]
# 190 [88.33, 93.0, 92.0, 94.67, 96.33, 96.67, 97.67, 96.0, 93.67, 94.67, 93.67, 92.33, 94.0, 94.0, 93.0, 93.0, 93.0, 91.33, 92.0, 92.0] ['64', '32', '32', '32'] 0.2 800 0.5 20 40
